# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("cleaned_data1.csv")
pd.set_option("display.max_columns",None)
data
# Out:
#        Age Gender MaritalStatus  DependentChildren  DependentsOther  \
# 0       48      M             M                  0                0
# 1       43      F             M                  0                0
# 2       30      M             U                  0                0
# 3       41      M             S                  0                0
# 4       36      M             M                  0                0
# ...    ...    ...           ...                ...              ...
# 53964   32      F             S                  0                0
# 53965   20      F             S                  0                0
# 53966   19      M             S                  0                0
# 53967   24      M             S                  0                0
# 53968   22      M             S                  0                0
#
#        WeeklyWages PartTimeFullTime  HoursWorkedPerWeek  DaysWorkedPerWeek  \
# ...

# %%
data.dtypes
# Out:
# Age                             int64
# Gender                         object
# MaritalStatus                  object
# DependentChildren               int64
# DependentsOther                 int64
# WeeklyWages                   float64
# PartTimeFullTime               object
# HoursWorkedPerWeek            float64
# DaysWorkedPerWeek               int64
# ClaimDescriptionKeyword_0     float64
# ClaimDescriptionKeyword_1     float64
# ClaimDescriptionKeyword_2     float64
# ClaimDescriptionKeyword_3     float64
# ClaimDescriptionKeyword_4     float64
# ClaimDescriptionKeyword_5     float64
# ClaimDescriptionKeyword_6     float64
# ClaimDescriptionKeyword_7     float64
# ClaimDescriptionKeyword_8     float64
# ClaimDescriptionKeyword_9     float64
# ClaimDescriptionKeyword_10    float64
# ClaimDescriptionKeyword_11    float64
# InitialIncurredClaimsCost       int64
# UltimateIncurredClaimCost     float64
# DaysGap                         int64
# dtype: object

# %%
# supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd',
# 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 
# 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r',
# 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 
# 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray',
# 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray',
# 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 
# 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 
# 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r

# %%
# heatmap
plt.subplots(figsize=(20,10))
sns.heatmap(data.corr(),cmap="OrRd",annot=True)
# Out:
# <AxesSubplot:>

# %%
#pie chart

labels = ["MALE","FEMALE"]
gender = [ len(data[data["Gender"]=="M"].index.to_list()) , len(data[data["Gender"]=="F"].index.to_list())]
#colours
colours = [ "#ff6666" , "#66b3ff"]
#explosion
explode = [0.05,0.05]
fig1,ax1 = plt.subplots()
plt.pie(gender , colors=colours , labels=labels , autopct="%1.1f%%",wedgeprops = {'linewidth': 1},startangle=60,pctdistance=0.85)
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc="white")
fig=plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis("equal")
ax1.set_title("Pie Chart - MALE vs FEMALE" , fontsize=13,loc="right")
plt.tight_layout()
plt.legend()
plt.show()

# %%
#pie chart

labels = ["FULLTIME","PARTTIME"]
gender = [ len(data[data["PartTimeFullTime"]=="F"].index.to_list()) , len(data[data["PartTimeFullTime"]=="P"].index.to_list())]
#colours
colours = [ "#ff6666" , "#66b3ff" ]
#explosion
explode = [0.05,0.05]
fig1,ax1 = plt.subplots()
plt.pie(gender , colors=colours , labels=labels,explode=explode, autopct="%1.1f%%",wedgeprops = {'linewidth': 1},startangle=30,pctdistance=0.85)
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc="white")
fig=plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis("equal")
ax1.set_title("Pie Chart - FULLTIME vs PARTTIME" , fontsize=13,loc="right")
plt.tight_layout()
plt.legend()
plt.show()

# %%
#pie chart

labels = ["MARRIED","SINGLE","UNKNOWN"]
gender = [ len(data[data["MaritalStatus"]=="M"].index.to_list()) , len(data[data["MaritalStatus"]=="S"].index.to_list()) , len(data[data["MaritalStatus"]=="U"].index.to_list())]
#colours
colours = [ "#ff9999" , "#66b3ff" , "#99ff99"]
#explosion
explode = [0.02,0,0.05]
fig1,ax1 = plt.subplots()
plt.pie(gender , colors=colours , labels=labels , autopct="%1.1f%%",explode=explode,startangle=30,pctdistance=0.85)
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc="white")
fig=plt.gcf()
fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis("equal")
ax1.set_title("Pie Chart - Marital Status" , fontsize=13,loc="right")
plt.tight_layout()
plt.legend()
plt.show()

# %%
numerical_features = [feature for feature in data.columns if data[feature].dtypes != 'O' and data[feature].dtypes != 'bool']
categorical_features = [feature for feature in data.columns if data[feature].dtypes == 'O']
bool_features = [feature for feature in data.columns if data[feature].dtypes == 'bool']

print(numerical_features,categorical_features,bool_features)
# Out:
# ['Age', 'DependentChildren', 'DependentsOther', 'WeeklyWages', 'HoursWorkedPerWeek', 'DaysWorkedPerWeek', 'ClaimDescriptionKeyword_0', 'ClaimDescriptionKeyword_1', 'ClaimDescriptionKeyword_2', 'ClaimDescriptionKeyword_3', 'ClaimDescriptionKeyword_4', 'ClaimDescriptionKeyword_5', 'ClaimDescriptionKeyword_6', 'ClaimDescriptionKeyword_7', 'ClaimDescriptionKeyword_8', 'ClaimDescriptionKeyword_9', 'ClaimDescriptionKeyword_10', 'ClaimDescriptionKeyword_11', 'InitialIncurredClaimsCost', 'UltimateIncurredClaimCost', 'DaysGap'] ['Gender', 'MaritalStatus', 'PartTimeFullTime'] []

# %%
# Numerical Columns List
numerical_columns = ['Age', 'DependentChildren', 'DependentsOther', 'WeeklyWages', 'HoursWorkedPerWeek', 'DaysWorkedPerWeek', 'DaysGap', 'ClaimDescriptionKeyword_0', 'ClaimDescriptionKeyword_1', 'ClaimDescriptionKeyword_2', 'ClaimDescriptionKeyword_3', 'ClaimDescriptionKeyword_4', 'ClaimDescriptionKeyword_5', 'ClaimDescriptionKeyword_6', 'ClaimDescriptionKeyword_7', 'ClaimDescriptionKeyword_8', 'ClaimDescriptionKeyword_9', 'ClaimDescriptionKeyword_10', 'ClaimDescriptionKeyword_11', 'InitialIncurredClaimsCost', 'UltimateIncurredClaimCost']
# Splitup of Numerical Columns for Visualizing purpose
numerical_col_cd = ["ClaimDescriptionKeyword_0","ClaimDescriptionKeyword_1","ClaimDescriptionKeyword_2","ClaimDescriptionKeyword_3","ClaimDescriptionKeyword_4","ClaimDescriptionKeyword_5","ClaimDescriptionKeyword_6","ClaimDescriptionKeyword_7","ClaimDescriptionKeyword_8","ClaimDescriptionKeyword_9","ClaimDescriptionKeyword_10","ClaimDescriptionKeyword_11"]
numerical_col_wo_cd = ["Age", "DependentChildren", "DependentsOther","WeeklyWages","HoursWorkedPerWeek","DaysWorkedPerWeek",'DaysGap', 'InitialIncurredClaimsCost', 'UltimateIncurredClaimCost']
# Continuous numerical columns
con_numerical_col_wo_cd = [continuous_val for continuous_val in numerical_col_wo_cd if data[continuous_val].dtypes=="float64"]
print(con_numerical_col_wo_cd)
# Discrete numerical columns
dis_numerical_col_wo_cd = [ discrete_val for discrete_val in numerical_col_wo_cd if data[discrete_val].dtypes == "int64"]
print(dis_numerical_col_wo_cd)
# Categorical Columns
categorical_col = ['Gender', 'MaritalStatus', 'PartTimeFullTime']
# Out:
# ['WeeklyWages', 'HoursWorkedPerWeek', 'UltimateIncurredClaimCost']
# ['Age', 'DependentChildren', 'DependentsOther', 'DaysWorkedPerWeek', 'DaysGap', 'InitialIncurredClaimsCost']

# %%
#g = sns.PairGrid(data)
#g.map_diag(sns.histplot)
#g.map_offdiag(sns.scatterplot)

# %%
a=0
fig,axes = plt.subplots(3, 4, figsize=(25, 10))
  
fig.suptitle('HISTPLOT FOR ALL CLAIM DESCRIPTION')
  
for i in range(3):
    for j in range(4):
        sns.histplot(ax=axes[i, j], data=data, x=numerical_col_cd[a],bins=30)
        a+=1

# %%
a=0
fig,axes = plt.subplots(3, 4, figsize=(25, 10))
  
fig.suptitle('BOXPLOT FOR ALL CLAIM DESCRIPTION')
  
for i in range(3):
    for j in range(4):
        sns.boxplot(ax=axes[i, j], data=data, x=numerical_col_cd[a],color="Red")
        a+=1

# %%
a=0
fig,axes = plt.subplots(3, 4, figsize=(25, 10))
  
fig.suptitle('SCATTERPLOT FOR ALL CLAIM DESCRIPTION ON ULTIMATEINCURREDCLAIMCOST ')
  
for i in range(3):
    for j in range(4):
        sns.scatterplot(ax=axes[i, j], data=data, x=numerical_col_cd[a],y="UltimateIncurredClaimCost")
        a+=1

# %%
fig,axes = plt.subplots(1,3, figsize=(20, 5))
a=0
fig.suptitle('CONTINUOUS NUMERICAL COLUMNS ON ULTIMATEINCURREDCLAIMCOST')
  

for j in range(3):
    sns.scatterplot(ax=axes[ j], data=data, x=con_numerical_col_wo_cd[a],y="UltimateIncurredClaimCost")
    a+=1

# %%
fig,axes = plt.subplots(1,3, figsize=(25, 5))
a=0
fig.suptitle('HISTPLOT FOR ALL CONTINUOUS COLUMNS W/O CLAIMDESCRIPTION')
  

for j in range(3):
        sns.histplot(ax=axes[j], data=data, x=con_numerical_col_wo_cd[a],bins=60)
        a+=1

# %%
a=0
fig,axes = plt.subplots(1, 3, figsize=(25, 5))
  
fig.suptitle('BOXPLOT FOR ALL CLAIM DESCRIPTION')
  

for j in range(3):
    sns.boxplot(ax=axes[ j], data=data, x=con_numerical_col_wo_cd[a],color="Red")
    a+=1

# %%
fig,axes = plt.subplots(2,3, figsize=(25, 10))
a=0
fig.suptitle('HISTPLOT FOR ALL CONTINUOUS COLUMNS W/O CLAIMDESCRIPTION')
  
for i in range(2):
    for j in range(3):
        sns.histplot(ax=axes[i, j], data=data, x=dis_numerical_col_wo_cd[a],bins=60)
        a+=1

# %%
a=0
fig,axes = plt.subplots(2, 3, figsize=(25, 10))
  
fig.suptitle('BOXPLOT FOR ALL CLAIM DESCRIPTION')
  
for i in range(2):
    for j in range(3):
        sns.boxplot(ax=axes[i, j], data=data, x=dis_numerical_col_wo_cd[a],color="Red")
        a+=1

# %%
def Outlier(dataset,feature):
    shape1 = dataset.shape[0]                                 #taking the shape before removing outliers to keep track of no of outliers
    lst = sorted(dataset[feature])                            #taking a list of sorted values of that column
    
    quantile1, quantile3 = np.percentile(lst,[25,75])         #obtaining 25th and 75th percentile
    iqr_value = quantile3 - quantile1                         #finding inter-quartile value(difference)
    
    #obtaining lower bound and upper bound
    lower_bound_val = quantile1 - (1.5 * iqr_value)
    upper_bound_val = quantile3 + (1.5 * iqr_value)
    
    dataset.drop(dataset[(dataset[feature] <= lower_bound_val)].index,0,inplace=True) #Dropping the rows having values below lower bound value
    dataset.drop(dataset[(dataset[feature] >= upper_bound_val)].index,0,inplace=True) #Dropping the rows having values above upper bound value
    
    return shape1-(dataset.shape[0])

# %%
data1 = data.copy()
print(data1.shape)
for feature in con_numerical_col_wo_cd:
    shape1 = Outlier(data1,feature)
    print('\n {} has {} outliers'.format(feature, shape1))
data1.shape
# Out:
# (53969, 24)
#
#  WeeklyWages has 1491 outliers
#
#  HoursWorkedPerWeek has 7685 outliers
#
#  UltimateIncurredClaimCost has 5371 outliers
# (39422, 24)

# %%
outlier_discrete = ["Age", 'DaysGap', 'InitialIncurredClaimsCost']
data2 = data1.copy()
print(data2.shape)
for feature in outlier_discrete:
    shape1 = Outlier(data2,feature)
    print('\n {} has {} outliers'.format(feature, shape1))
data2.shape
# Out:
# (39422, 24)
#
#  Age has 69 outliers
#
#  DaysGap has 3675 outliers
#
#  InitialIncurredClaimsCost has 1880 outliers
# (33798, 24)

# %%
a=0
fig,axes = plt.subplots(1, 3, figsize=(25, 5))
  
fig.suptitle('BOXPLOT FOR ALL CLAIM DESCRIPTION')
  

for j in range(3):
    sns.boxplot(ax=axes[ j], data=data1, x=con_numerical_col_wo_cd[a],color="Red")
    a+=1

# %%
fig,axes = plt.subplots(1,3, figsize=(25, 5))
a=0
fig.suptitle('HISTPLOT FOR ALL CONTINUOUS COLUMNS W/O CLAIMDESCRIPTION')
  

for j in range(3):
        sns.histplot(ax=axes[j], data=data1, x=con_numerical_col_wo_cd[a],bins=60)
        a+=1

# %%
a=0
fig,axes = plt.subplots(2, 3, figsize=(25, 10))
  
fig.suptitle('BOXPLOT FOR ALL CLAIM DESCRIPTION')
  
for i in range(2):
    for j in range(3):
        sns.boxplot(ax=axes[i, j], data=data1, x=dis_numerical_col_wo_cd[a],color="Red")
        a+=1

# %%
import matplotlib.gridspec as gs
fig = plt.figure(figsize=(28, 7), constrained_layout=False)
gs = gs.GridSpec(1, 3, figure=fig)
plt.suptitle('Count of Categorical Data\n')

ax_1 = fig.add_subplot(gs[0, 0])
sns.countplot(data=data, x='Gender', ax=ax_1)
plt.title('Count of Gender')


ax_2 = fig.add_subplot(gs[0, 1])
sns.countplot(data=data, x='MaritalStatus', ax=ax_2)
plt.title('Count of MaritalStatus')


ax_3 = fig.add_subplot(gs[0, 2])
sns.countplot(data=data, x='PartTimeFullTime', ax=ax_3)
plt.title('Count of PartTimeFullTime')
# Out:
# Text(0.5, 1.0, 'Count of PartTimeFullTime')

# %%
import matplotlib.gridspec as gs
fig=plt.figure( figsize=(17,8))
gs = gs.GridSpec(1, 2, figure=fig)

plt.suptitle(" DEPENDENT CHILDREN & DEPENDENT OTHERS ON ULTIMATEINCURREDCLAIMCOST")

ax1=fig.add_subplot(gs[0,0])
sns.scatterplot(y="UltimateIncurredClaimCost",x="DependentChildren",data=data,ax=ax1)
plt.title("DEPENDENT CHILDREN VS ULTIMATEINCURREDCLAIMCOST")

ax2=fig.add_subplot(gs[0,1])
sns.scatterplot(y="UltimateIncurredClaimCost",x="DependentsOther",data=data,ax=ax2)
plt.title("DEPENDENT OTHER VS ULTIMATEINCURREDCLAIMCOST")
# Out:
# Text(0.5, 1.0, 'DEPENDENT OTHER VS ULTIMATEINCURREDCLAIMCOST')

# %%
sns.scatterplot(x="InitialIncurredClaimsCost",y="UltimateIncurredClaimCost",data=data)
# Out:
# <AxesSubplot:xlabel='InitialIncurredClaimsCost', ylabel='UltimateIncurredClaimCost'>

# %%
sns.scatterplot(x="InitialIncurredClaimsCost",y="UltimateIncurredClaimCost",data=data2)
# Out:
# <AxesSubplot:xlabel='InitialIncurredClaimsCost', ylabel='UltimateIncurredClaimCost'>

# %%
print(max(data["UltimateIncurredClaimCost"]))
print(max(data1["UltimateIncurredClaimCost"]))
# Out:
# 4027135.935
# 17341.49384

# %%
print(max(data["InitialIncurredClaimsCost"]))
print(max(data1["InitialIncurredClaimsCost"]))
# Out:
# 2000000
# 40000

# %%
fig,axes = plt.subplots(1,3, figsize=(25, 5))
a=0
fig.suptitle('HISTPLOT FOR ALL CONTINUOUS COLUMNS W/O CLAIMDESCRIPTION')
  

for j in range(3):
        sns.histplot(ax=axes[j], data=data2, x=outlier_discrete[a],bins=60)
        a+=1

# %%
a=0
fig,axes = plt.subplots(1, 3, figsize=(25, 5))
  
fig.suptitle('BOXPLOT FOR ALL CLAIM DESCRIPTION')
  

for j in range(3):
    sns.boxplot(ax=axes[ j], data=data2, x=outlier_discrete[a],color="Red")
    a+=1

# %%
def valuecounts(a):
    print(data2[a].value_counts())
    

valuecounts("DaysWorkedPerWeek")
valuecounts("DependentChildren")
valuecounts("DependentsOther")
# Out:
# 5    33227
# 4      275
# 6      129
# 3      115
# 7       28
# 2       15
# 1        9
# Name: DaysWorkedPerWeek, dtype: int64
# 0    31886
# 2      778
# 1      702
# 3      301
# 4      103
# 5       26
# 6        2
# Name: DependentChildren, dtype: int64
# 0    33561
# 1      212
# 2       19
# 3        6
# Name: DependentsOther, dtype: int64

# %%
data2.shape
# Out:
# (33798, 24)
